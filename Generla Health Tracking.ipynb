# %% [markdown]
# # Description

# %% [markdown]
# Import, transform, and analysis (mean, mode, SD) of Google fit data.

# %% [markdown]
# # Import Python Libraries

# %% [markdown]
# ## Visualization / Heatmap Libraries

# %%
#%matplotlib notebook
#%matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataframe and Math Function Libraries

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
#!pip install --upgrade pip
#!pip install xlrd

# %% [markdown]
# # Load Data And Explore

# %% [markdown]
# ## Google Download (eventually API)
#
# This code uses a single file fromGoogle's Fit downlad, a summary file that is aggegated from the other files. Download yor Google Fit data from the following link, https://takeout.google.com/, and then reference the summary file in the Import section.

# %% [markdown]
# ## Import

# %%
import os
os_name = os.sys.platform

fileName = '2021-11-20 Daily Summaries.csv'
#Mac Path
if os_name == 'darwin':
    filePath = '/Users/igoeja/Documents/GitHub/DataAnalytics/Data/' + fileName
else:
    filePath = 'c:\\Users\\igoej\\OneDrive\\Documents\\GitHub\\DataAnalytics\\Data\\' + fileName

df_fit = pd.read_csv(filePath)
df_fit.tail()
df_fit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Date                                     3047 non-null   object
#  1   Move Minutes count                       1350 non-null   float64
#  2   Average blood glucose (mmol/L)           581 non-null    float64
#  3   Max blood glucose (mmol/L)               581 non-null    float64
#  4   Min blood glucose (mmol/L)               581 non-null    float64
#  5   Temporal relation to meal                0 non-null      float64
#  6   Meal type                                0 non-null      float64
#  7   Temporal relation to sleep               0 non-null      float64
#  8   Blood glucose specimen source            581 non-null    object
#  9   Average systolic blood pressure (mmHg)   149 non-null    float64
#  10  Max systolic blood pressure (mmHg)       149 non-null    float64
#  11  Min systolic blood pressure (mmHg)       149 non-null    float64
#  12  Average diastolic blood pressure (mmHg)  149 non-null    float64
#  13  Max diastolic blood pressure (mmHg)      149 non-null    float64
#  14  Min diastolic blood pressure (mmHg)      149 non-null    float64
#  15  Body position                            0 non-null      float64
#  16  Blood pressure measurement location      0 non-null      float64
#  17  Calories (kcal)                          2865 non-null   float64
#  18  Distance (m)                             2375 non-null   float64
#  19  Heart Points                             1162 non-null   float64
#  20  Heart Minutes                            1162 non-null   float64
#  21  Average heart rate (bpm)                 1099 non-null   float64
#  22  Max heart rate (bpm)                     1099 non-null   float64
#  23  Min heart rate (bpm)                     1099 non-null   float64
#  24  Low latitude (deg)                       1165 non-null   float64
#  25  Low longitude (deg)                      1165 non-null   float64
#  26  High latitude (deg)                      1165 non-null   float64
#  27  High longitude (deg)                     1165 non-null   float64
#  28  Average speed (m/s)                      2168 non-null   float64
#  29  Max speed (m/s)                          2168 non-null   float64
#  30  Min speed (m/s)                          2168 non-null   float64
#  31  Step count                               2430 non-null   float64
#  32  Average weight (kg)                      1554 non-null   float64
#  33  Max weight (kg)                          1554 non-null   float64
#  34  Min weight (kg)                          1554 non-null   float64
#  35  Biking duration (ms)                     202 non-null    float64
#  36  Inactive duration (ms)                   2143 non-null   float64
#  37  Unknown duration (ms)                    1 non-null      float64
#  38  Walking duration (ms)                    2262 non-null   float64
#  39  Running duration (ms)                    338 non-null    float64
#  40  Basketball duration (ms)                 29 non-null     float64
#  41  Stationary biking duration (ms)          69 non-null     float64
#  42  Elliptical duration (ms)                 48 non-null     float64
#  43  Rowing duration (ms)                     143 non-null    float64
#  44  Rowing machine duration (ms)             183 non-null    float64
#  45  Treadmill running duration (ms)          13 non-null     float64
#  46  Cross-country skiing duration (ms)       9 non-null      float64
#  47  Sleep duration (ms)                      162 non-null    float64
#  48  Stair climbing machine duration (ms)     1 non-null      float64
#  49  Strength training duration (ms)          4 non-null      float64
#  50  Ergometer duration (ms)                  11 non-null     float64
#  51  Other duration (ms)                      157 non-null    float64
#  52  Light sleeping duration (ms)             246 non-null    float64
#  53  Deep sleeping duration (ms)              245 non-null    float64
#  54  Awake mid-sleeping duration (ms)         179 non-null    float64
#  55  Guided breathing duration (ms)           11 non-null     float64
# dtypes: float64(54), object(2)
# memory usage: 1.3+ MB

# %% [markdown]
# # Shared Functions

# %% [markdown]
# ## Basic

# %%
def MedianFunction(df, roundValue):
    import statistics as stat
    cleaned = df.dropna()
    return round(stat.median(cleaned), roundValue)

# %%
def AverageFunction(df, roundValue):
    cleaned = df.dropna()
    return round(sum(cleaned)/len(cleaned), roundValue)

# %% [markdown]
# # Data Clean and Prep

# %%
df_fit.dropna(axis=1, how='all', inplace=True)

# %% [markdown]
# # Google Specific Fixes

# %%
df_fit.set_index('Date')
# Out:
#             Move Minutes count  Average blood glucose (mmol/L)  \
# Date
# 2012-09-18                 NaN                             NaN
# 2012-09-19                 NaN                             NaN
# 2012-09-20                 NaN                             NaN
# 2012-09-21                 NaN                             NaN
# 2012-09-22                 NaN                             NaN
# ...                        ...                             ...
# 2021-11-16                28.0                             NaN
# 2021-11-17                86.0                             NaN
# 2021-11-18               117.0                             NaN
# 2021-11-19                64.0                             NaN
# 2021-11-20                 1.0                             NaN
#
#             Max blood glucose (mmol/L)  Min blood glucose (mmol/L)  \
# Date
# 2012-09-18                         NaN                         NaN
# 2012-09-19                         NaN                         NaN
# 2012-09-20                         NaN                         NaN
# 2012-09-21                         NaN                         NaN
# 2012-09-22                         NaN                         NaN
# ...                                ...                         ...
# 2021-11-16                         NaN                         NaN
# 2021-11-17                         NaN                         NaN
# 2021-11-18                         NaN                         NaN
# 2021-11-19                         NaN                         NaN
# 2021-11-20                         NaN                         NaN
#
#            Blood glucose specimen source  \
# Date
# 2012-09-18                           NaN
# 2012-09-19                           NaN
# 2012-09-20                           NaN
# 2012-09-21                           NaN
# 2012-09-22                           NaN
# ...                                  ...
# 2021-11-16                           NaN
# 2021-11-17                           NaN
# 2021-11-18                           NaN
# 2021-11-19                           NaN
# 2021-11-20                           NaN
#
#             Average systolic blood pressure (mmHg)  \
# Date
# 2012-09-18                                     NaN
# 2012-09-19                                     NaN
# 2012-09-20                                     NaN
# 2012-09-21                                     NaN
# 2012-09-22                                     NaN
# ...                                            ...
# 2021-11-16                                     NaN
# 2021-11-17                                     NaN
# 2021-11-18                                     NaN
# 2021-11-19                                     NaN
# 2021-11-20                                     NaN
#
#             Max systolic blood pressure (mmHg)  \
# Date
# 2012-09-18                                 NaN
# 2012-09-19                                 NaN
# 2012-09-20                                 NaN
# 2012-09-21                                 NaN
# 2012-09-22                                 NaN
# ...                                        ...
# 2021-11-16                                 NaN
# 2021-11-17                                 NaN
# 2021-11-18                                 NaN
# 2021-11-19                                 NaN
# 2021-11-20                                 NaN
#
#             Min systolic blood pressure (mmHg)  \
# Date
# 2012-09-18                                 NaN
# 2012-09-19                                 NaN
# 2012-09-20                                 NaN
# 2012-09-21                                 NaN
# 2012-09-22                                 NaN
# ...                                        ...
# 2021-11-16                                 NaN
# 2021-11-17                                 NaN
# 2021-11-18                                 NaN
# 2021-11-19                                 NaN
# 2021-11-20                                 NaN
#
#             Average diastolic blood pressure (mmHg)  \
# Date
# 2012-09-18                                      NaN
# 2012-09-19                                      NaN
# 2012-09-20                                      NaN
# 2012-09-21                                      NaN
# 2012-09-22                                      NaN
# ...                                             ...
# 2021-11-16                                      NaN
# 2021-11-17                                      NaN
# 2021-11-18                                      NaN
# 2021-11-19                                      NaN
# 2021-11-20                                      NaN
#
#             Max diastolic blood pressure (mmHg)  ...  \
# Date                                             ...
# 2012-09-18                                  NaN  ...
# 2012-09-19                                  NaN  ...
# 2012-09-20                                  NaN  ...
# 2012-09-21                                  NaN  ...
# 2012-09-22                                  NaN  ...
# ...                                         ...  ...
# 2021-11-16                                  NaN  ...
# 2021-11-17                                  NaN  ...
# 2021-11-18                                  NaN  ...
# 2021-11-19                                  NaN  ...
# 2021-11-20                                  NaN  ...
#
#             Cross-country skiing duration (ms)  Sleep duration (ms)  \
# Date
# 2012-09-18                                 NaN                  NaN
# 2012-09-19                                 NaN                  NaN
# 2012-09-20                                 NaN                  NaN
# 2012-09-21                                 NaN                  NaN
# 2012-09-22                                 NaN                  NaN
# ...                                        ...                  ...
# 2021-11-16                                 NaN                  NaN
# 2021-11-17                                 NaN                  NaN
# 2021-11-18                                 NaN                  NaN
# 2021-11-19                                 NaN                  NaN
# 2021-11-20                                 NaN                  NaN
#
#             Stair climbing machine duration (ms)  \
# Date
# 2012-09-18                                   NaN
# 2012-09-19                                   NaN
# 2012-09-20                                   NaN
# 2012-09-21                                   NaN
# 2012-09-22                                   NaN
# ...                                          ...
# 2021-11-16                                   NaN
# 2021-11-17                                   NaN
# 2021-11-18                                   NaN
# 2021-11-19                                   NaN
# 2021-11-20                                   NaN
#
#             Strength training duration (ms)  Ergometer duration (ms)  \
# Date
# 2012-09-18                              NaN                      NaN
# 2012-09-19                              NaN                      NaN
# 2012-09-20                              NaN                      NaN
# 2012-09-21                              NaN                      NaN
# 2012-09-22                              NaN                      NaN
# ...                                     ...                      ...
# 2021-11-16                              NaN                      NaN
# 2021-11-17                              NaN                      NaN
# 2021-11-18                              NaN                      NaN
# 2021-11-19                              NaN                      NaN
# 2021-11-20                              NaN                      NaN
#
#             Other duration (ms)  Light sleeping duration (ms)  \
# Date
# 2012-09-18                  NaN                           NaN
# 2012-09-19                  NaN                           NaN
# 2012-09-20                  NaN                           NaN
# 2012-09-21                  NaN                           NaN
# 2012-09-22                  NaN                           NaN
# ...                         ...                           ...
# 2021-11-16                  NaN                           NaN
# 2021-11-17                  NaN                           NaN
# 2021-11-18                  NaN                           NaN
# 2021-11-19                  NaN                           NaN
# 2021-11-20                  NaN                           NaN
#
#             Deep sleeping duration (ms)  Awake mid-sleeping duration (ms)  \
# Date
# 2012-09-18                          NaN                               NaN
# 2012-09-19                          NaN                               NaN
# 2012-09-20                          NaN                               NaN
# 2012-09-21                          NaN                               NaN
# 2012-09-22                          NaN                               NaN
# ...                                 ...                               ...
# 2021-11-16                          NaN                               NaN
# 2021-11-17                          NaN                               NaN
# 2021-11-18                          NaN                               NaN
# 2021-11-19                          NaN                               NaN
# 2021-11-20                          NaN                               NaN
#
#             Guided breathing duration (ms)
# Date
# 2012-09-18                             NaN
# 2012-09-19                             NaN
# 2012-09-20                             NaN
# 2012-09-21                             NaN
# 2012-09-22                             NaN
# ...                                    ...
# 2021-11-16                             NaN
# 2021-11-17                             NaN
# 2021-11-18                             NaN
# 2021-11-19                             NaN
# 2021-11-20                             NaN
#
# [3047 rows x 50 columns]

# %% [markdown]
# ## Set Aggregate Values

# %%
df_fit['SleepSum'] = df_fit['Deep sleeping duration (ms)'] + df_fit['Light sleeping duration (ms)'] + df_fit['Sleep duration (ms)']
df_fit['sleepSumHours'] = df_fit['SleepSum'] / 3600000

# %%
df_fit['basketballMinutes'] = df_fit['Basketball duration (ms)'] / 60000
df_fit['rowingMachineMinutes'] = df_fit['Rowing machine duration (ms)']/ 60000

# %% [markdown]
# ## Lag/Shift Values

# %%
df_fit['rowingMachineMinutesShifted'] = df_fit['rowingMachineMinutes'].shift()
df_fit['moveMinutesCountShifted'] = df_fit['Move Minutes count'].shift()
df_fit['heartPointsShifted'] = df_fit['Heart Points'].shift()
df_fit['distanceShifted'] = df_fit['Distance (m)'].shift()
df_fit['basketballMinutesShifted'] = df_fit['basketballMinutes'].shift()

# %%
#df_fit.columns

# %% [markdown]
# ## Filter Data Set

# %%
#set data set for analysis
dfi = df_fit[df_fit['Date'] >= '2021-01-01']

df = dfi[['Date', 'Average heart rate (bpm)','Average weight (kg)','Average systolic blood pressure (mmHg)','Average diastolic blood pressure (mmHg)','Average blood glucose (mmol/L)','Heart Points','SleepSum', 'sleepSumHours','basketballMinutes', 'basketballMinutesShifted', 'rowingMachineMinutes','rowingMachineMinutesShifted', 'moveMinutesCountShifted','heartPointsShifted','Distance (m)', 'distanceShifted', 'Deep sleeping duration (ms)', 'Light sleeping duration (ms)', 'Max heart rate (bpm)','Min heart rate (bpm)']]

# %% [markdown]
# # Data Review

# %%
df.describe()
# Out:
#        Average heart rate (bpm)  Average weight (kg)  \
# count                296.000000            87.000000
# mean                  79.022016           107.036178
# std                   12.253411             0.730802
# min                   56.000000           104.741997
# 25%                   72.459851           106.467999
# 50%                   75.165212           107.001999
# 75%                   78.814570           107.514500
# max                  133.280962           108.709000
#
#        Average systolic blood pressure (mmHg)  \
# count                               54.000000
# mean                               126.943885
# std                                  8.212215
# min                                103.000000
# 25%                                123.125000
# 50%                                128.000000
# 75%                                131.000000
# max                                147.000000
#
#        Average diastolic blood pressure (mmHg)  \
# count                                54.000000
# mean                                 80.189930
# std                                   4.861625
# min                                  68.000000
# 25%                                  78.000000
# 50%                                  80.000000
# 75%                                  83.000000
# max                                  91.000000
#
#        Average blood glucose (mmol/L)  Heart Points      SleepSum  \
# count                      249.000000    267.000000  6.200000e+01
# mean                         8.005302     59.797753  2.341258e+07
# std                          1.059735     36.875174  4.172271e+06
# min                          3.130262      1.000000  1.092000e+07
# 25%                          7.336126     36.000000  2.139000e+07
# 50%                          8.032692     58.000000  2.412000e+07
# 75%                          8.686735     80.500000  2.529000e+07
# max                         11.059582    207.000000  3.552000e+07
#
#        sleepSumHours  basketballMinutes  basketballMinutesShifted  \
# count      62.000000           3.000000                  3.000000
# mean        6.503495          22.194956                 22.194956
# std         1.158964          14.097672                 14.097672
# min         3.033333           8.124800                  8.124800
# 25%         5.941667          15.132442                 15.132442
# 50%         6.700000          22.140083                 22.140083
# 75%         7.025000          29.230033                 29.230033
# max         9.866667          36.319983                 36.319983
#
#        rowingMachineMinutes  rowingMachineMinutesShifted  \
# count             88.000000                    88.000000
# mean              34.994261                    34.994261
# std               14.065926                    14.065926
# min                0.123517                     0.123517
# 25%               24.852313                    24.852313
# 50%               34.351033                    34.351033
# 75%               42.258396                    42.258396
# max               74.867100                    74.867100
#
#        moveMinutesCountShifted  heartPointsShifted  Distance (m)  \
# count               324.000000          267.000000    324.000000
# mean                 82.240741           59.797753   3793.591678
# std                  45.761504           36.875174   2777.477245
# min                   2.000000            1.000000     15.582250
# 25%                  49.750000           36.000000   1703.618018
# 50%                  80.000000           58.000000   2824.264244
# 75%                 106.250000           80.500000   5139.880964
# max                 224.000000          207.000000  12522.099504
#
#        distanceShifted  Deep sleeping duration (ms)  \
# count       324.000000                 1.210000e+02
# mean       3803.277431                 7.207934e+06
# std        2770.224620                 3.360473e+06
# min          15.582250                 3.000000e+05
# 25%        1706.952044                 4.680000e+06
# 50%        2834.207464                 7.320000e+06
# 75%        5139.880964                 9.780000e+06
# max       12522.099504                 1.440000e+07
#
#        Light sleeping duration (ms)  Max heart rate (bpm)  \
# count                  1.210000e+02            296.000000
# mean                   1.118926e+07            136.826068
# std                    4.895268e+06             21.823367
# min                    1.140000e+06             56.000000
# 25%                    8.280000e+06            125.147823
# 50%                    1.164000e+07            139.063301
# 75%                    1.404000e+07            153.000000
# max                    3.642000e+07            190.000000
#
#        Min heart rate (bpm)
# count            296.000000
# mean              55.714487
# std                9.734844
# min               40.000000
# 25%               50.000000
# 50%               53.000000
# 75%               56.141647
# max               98.000000

# %% [markdown]
# # Measures

# %% [markdown]
# ## Blood Pressure

# %%
dia = df['Average diastolic blood pressure (mmHg)'].dropna()
sys = df['Average systolic blood pressure (mmHg)'].dropna()
print('BP (avg):', AverageFunction(sys,1), '/', AverageFunction(dia,1))
print('BP (median):',MedianFunction(sys,1), '/', MedianFunction(dia,1))
print('BP (std):', round(sys.std(),1), '/', round(dia.std(),1))
# Out:
# BP (avg): 126.9 / 80.2
# BP (median): 128.0 / 80.0
# BP (std): 8.2 / 4.9

# %% [markdown]
# ## Glucose

# %%
bg = df['Average blood glucose (mmol/L)']
bg2 = df['Average blood glucose (mmol/L)'] * 18
print('BG (mmol/L):', AverageFunction(bg, 1))
print('BG (mmoL/L, std):', round(bg.std(),5))
print('BG (mmg/dl):', round(AverageFunction(bg2, 1)))
print('BG (mmg/dl, std):', round(bg2.std(),5))
# Out:
# BG (mmol/L): 8.0
# BG (mmoL/L, std): 1.05974
# BG (mmg/dl): 144
# BG (mmg/dl, std): 19.07523

# %% [markdown]
# ## Weight

# %%
w = df['Average weight (kg)']
print('Weight (kg):', AverageFunction(w, 1))
print('Weight (lbs):', round(AverageFunction(w, 1) * 2.2,1))
# Out:
# Weight (kg): 107.0
# Weight (lbs): 235.4

# %% [markdown]
# ## Sleep

# %%
print('Sleep:', AverageFunction(df['sleepSumHours'],2))
print('Sleep (Median):', MedianFunction(df['sleepSumHours'], 2))
# Out:
# Sleep: 6.5
# Sleep (Median): 6.7

# %% [markdown]
# ## Activity

# %%
print('Distance (m):', AverageFunction(df['Distance (m)'],2))
print('Distance (m) (Median):', MedianFunction(df['Distance (m)'], 2))
print()
print('Heart Points:', AverageFunction(df['Heart Points'],2))
print('Heart Points (Median):', MedianFunction(df['Heart Points'], 2))
print()
print('Move Minutes:', AverageFunction(df['moveMinutesCountShifted'],2))
print('Move Minutes (Median):', MedianFunction(df['moveMinutesCountShifted'], 2))
# Out:
# Distance (m): 3793.59
# Distance (m) (Median): 2824.26
#
# Heart Points: 59.8
# Heart Points (Median): 58.0
#
# Move Minutes: 82.24
# Move Minutes (Median): 80.0

# %% [markdown]
# ## Heart Rate

# %%
print('Average heart rate (bpm):', AverageFunction(df['Average heart rate (bpm)'],2))
print('Max heart rate (bpm):', AverageFunction(df['Max heart rate (bpm)'], 2))
print('Min heart rate (bpm):', AverageFunction(df['Min heart rate (bpm)'], 2))
# Out:
# Average heart rate (bpm): 79.02
# Max heart rate (bpm): 136.83
# Min heart rate (bpm): 55.71
